# %%
import pandas as pd
import pypandoc
import os
import re
from docx2pdf import convert
from docx import Document
import numpy as np

# %%
full_list = []

for file in [f for f in os.listdir('docs') if f != '.DS_Store']:
    doc = Document(f'docs/{file}')

    # Идентификаторы ведомости
    table_first = doc.tables[1]

    kvartal = int(table_first.rows[0].cells[1].text.strip())

    videl = int(table_first.rows[6].cells[1].text.strip())

    area = table_first.rows[0].cells[-1].text.strip().split('/')[1]
    area = float('.'.join(re.findall(r'\d+', area)))

    # Парсинг таблицы
    table_second = doc.tables[2]

    # взять породу 1
    poroda_cell_1 = table_second.rows[1].cells[0].text
    delovaya_dict_1 = {
        8:table_second.rows[1].cells[3].text.strip(),
        12:table_second.rows[2].cells[3].text.strip(),
        16:table_second.rows[3].cells[3].text.strip(),
        20:table_second.rows[4].cells[3].text.strip(),
        24:table_second.rows[5].cells[3].text.strip(),
        28:table_second.rows[6].cells[3].text.strip(),
        32:table_second.rows[7].cells[3].text.strip(),
    }

    polu_delovaya_dict_1 = {
        8:table_second.rows[1].cells[4].text.strip(),
        12:table_second.rows[2].cells[4].text.strip(),
        16:table_second.rows[3].cells[4].text.strip(),
        20:table_second.rows[4].cells[4].text.strip(),
        24:table_second.rows[5].cells[4].text.strip(),
        28:table_second.rows[6].cells[4].text.strip(),
        32:table_second.rows[7].cells[4].text.strip(),
    }

    drovyanaya_dict_1 = {
        8:table_second.rows[1].cells[5].text.strip(),
        12:table_second.rows[2].cells[5].text.strip(),
        16:table_second.rows[3].cells[5].text.strip(),
        20:table_second.rows[4].cells[5].text.strip(),
        24:table_second.rows[5].cells[5].text.strip(),
        28:table_second.rows[6].cells[5].text.strip(),
        32:table_second.rows[7].cells[5].text.strip(),
    }

    suhostoi_dict_1 = {
        8:table_second.rows[1].cells[6].text.strip(),
        12:table_second.rows[2].cells[6].text.strip(),
        16:table_second.rows[3].cells[6].text.strip(),
        20:table_second.rows[4].cells[6].text.strip(),
        24:table_second.rows[5].cells[6].text.strip(),
        28:table_second.rows[6].cells[6].text.strip(),
        32:table_second.rows[7].cells[6].text.strip(),
    }

    nevelik_dict_1 = {
        8:table_second.rows[1].cells[7].text.strip(),
        12:table_second.rows[2].cells[7].text.strip(),
        16:table_second.rows[3].cells[7].text.strip(),
        20:table_second.rows[4].cells[7].text.strip(),
        24:table_second.rows[5].cells[7].text.strip(),
        28:table_second.rows[6].cells[7].text.strip(),
        32:table_second.rows[7].cells[7].text.strip(),
    }






    # взять породу 2
    poroda_cell_2 = table_second.rows[9].cells[0].text
    delovaya_dict_2 = {
        8:table_second.rows[9].cells[3].text.strip(),
        12:table_second.rows[10].cells[3].text.strip(),
        16:table_second.rows[11].cells[3].text.strip(),
        20:table_second.rows[12].cells[3].text.strip(),
        24:table_second.rows[13].cells[3].text.strip(),
        28:table_second.rows[14].cells[3].text.strip(),
        32:table_second.rows[15].cells[3].text.strip(),
    }

    polu_delovaya_dict_2 = {
        8:table_second.rows[9].cells[4].text.strip(),
        12:table_second.rows[10].cells[4].text.strip(),
        16:table_second.rows[11].cells[4].text.strip(),
        20:table_second.rows[12].cells[4].text.strip(),
        24:table_second.rows[13].cells[4].text.strip(),
        28:table_second.rows[14].cells[4].text.strip(),
        32:table_second.rows[15].cells[4].text.strip(),
    }

    drovyanaya_dict_2 = {
        8:table_second.rows[9].cells[5].text.strip(),
        12:table_second.rows[10].cells[5].text.strip(),
        16:table_second.rows[11].cells[5].text.strip(),
        20:table_second.rows[12].cells[5].text.strip(),
        24:table_second.rows[13].cells[5].text.strip(),
        28:table_second.rows[14].cells[5].text.strip(),
        32:table_second.rows[15].cells[5].text.strip(),
    }

    suhostoi_dict_2 = {
        8:table_second.rows[9].cells[6].text.strip(),
        12:table_second.rows[10].cells[6].text.strip(),
        16:table_second.rows[11].cells[6].text.strip(),
        20:table_second.rows[12].cells[6].text.strip(),
        24:table_second.rows[13].cells[6].text.strip(),
        28:table_second.rows[14].cells[6].text.strip(),
        32:table_second.rows[15].cells[6].text.strip(),
    }

    nevelik_dict_2 = {
        8:table_second.rows[9].cells[7].text.strip(),
        12:table_second.rows[10].cells[7].text.strip(),
        16:table_second.rows[11].cells[7].text.strip(),
        20:table_second.rows[12].cells[7].text.strip(),
        24:table_second.rows[13].cells[7].text.strip(),
        28:table_second.rows[14].cells[7].text.strip(),
        32:table_second.rows[15].cells[7].text.strip(),
    }






    try:
        # взять породу 3
        poroda_cell_3 = table_second.rows[17].cells[0].text
        delovaya_dict_3 = {
            8:table_second.rows[17].cells[3].text.strip(),
            12:table_second.rows[18].cells[3].text.strip(),
            16:table_second.rows[19].cells[3].text.strip(),
            20:table_second.rows[20].cells[3].text.strip(),
            24:table_second.rows[21].cells[3].text.strip(),
            28:table_second.rows[22].cells[3].text.strip(),
            32:table_second.rows[23].cells[3].text.strip(),
        }

        polu_delovaya_dict_3 = {
            8:table_second.rows[17].cells[4].text.strip(),
            12:table_second.rows[18].cells[4].text.strip(),
            16:table_second.rows[19].cells[4].text.strip(),
            20:table_second.rows[20].cells[4].text.strip(),
            24:table_second.rows[21].cells[4].text.strip(),
            28:table_second.rows[22].cells[4].text.strip(),
            32:table_second.rows[23].cells[4].text.strip(),
        }

        drovyanaya_dict_3 = {
            8:table_second.rows[17].cells[5].text.strip(),
            12:table_second.rows[18].cells[5].text.strip(),
            16:table_second.rows[19].cells[5].text.strip(),
            20:table_second.rows[20].cells[5].text.strip(),
            24:table_second.rows[21].cells[5].text.strip(),
            28:table_second.rows[22].cells[5].text.strip(),
            32:table_second.rows[23].cells[5].text.strip(),
        }

        suhostoi_dict_3 = {
            8:table_second.rows[17].cells[6].text.strip(),
            12:table_second.rows[18].cells[6].text.strip(),
            16:table_second.rows[19].cells[6].text.strip(),
            20:table_second.rows[20].cells[6].text.strip(),
            24:table_second.rows[21].cells[6].text.strip(),
            28:table_second.rows[22].cells[6].text.strip(),
            32:table_second.rows[23].cells[6].text.strip(),
        }

        nevelik_dict_3 = {
            8:table_second.rows[17].cells[7].text.strip(),
            12:table_second.rows[18].cells[7].text.strip(),
            16:table_second.rows[19].cells[7].text.strip(),
            20:table_second.rows[20].cells[7].text.strip(),
            24:table_second.rows[21].cells[7].text.strip(),
            28:table_second.rows[22].cells[7].text.strip(),
            32:table_second.rows[23].cells[7].text.strip(),
        }

        
        list_porod = {poroda_cell_1:
                        {'деловая':delovaya_dict_1,
                        'полуделовая':polu_delovaya_dict_1,
                        'дровяная':drovyanaya_dict_1,
                        'сухостой':suhostoi_dict_1,
                        'невелик':nevelik_dict_1},
                    poroda_cell_2:
                        {'деловая':delovaya_dict_2,
                        'полуделовая':polu_delovaya_dict_2,
                        'дровяная':drovyanaya_dict_2,
                        'сухостой':suhostoi_dict_2,
                        'невелик':nevelik_dict_2},
                    poroda_cell_3:
                        {'деловая':delovaya_dict_3,
                        'полуделовая':polu_delovaya_dict_3,
                        'дровяная':drovyanaya_dict_3,
                        'сухостой':suhostoi_dict_3,
                        'невелик':nevelik_dict_3}
                        }

    except:
            list_porod = {poroda_cell_1:
                        {'деловая':delovaya_dict_1,
                        'полуделовая':polu_delovaya_dict_1,
                        'дровяная':drovyanaya_dict_1,
                        'сухостой':suhostoi_dict_1,
                        'невелик':nevelik_dict_1},
                    poroda_cell_2:
                        {'деловая':delovaya_dict_2,
                        'полуделовая':polu_delovaya_dict_2,
                        'дровяная':drovyanaya_dict_2,
                        'сухостой':suhostoi_dict_2,
                        'невелик':nevelik_dict_2}
                        }
    

    dict_i = {'квартал':kvartal,
             'выдел':videl,
             'площадь':area,
            'таблица':list_porod}

    full_list.append(dict_i)

# %%
def find_table(kvartal, videl, area):
    for k in full_list:
        if (k['квартал'] == kvartal)&(k['выдел'] == videl)&(k['площадь'] == area):
            return k['таблица']
        else:
            continue

# %%
excel_df = pd.read_excel('add_kniga.xlsx') 
excel_df['Площадь'] = excel_df['Площадь'].apply(lambda x: x if x == 'Площадь' else round(float(x),3))

# %%
for kkk in full_list:

    filtered_row_index = excel_df[(excel_df['Квартал'] == kkk['квартал']) &
                              (excel_df['Выдел, который пишем в ведомостях'] == kkk['выдел']) &
                              (excel_df['Площадь'] == kkk['площадь'])].index
    
    try:
        new_values_el = {
        'Ель': kkk['таблица']['Е']['деловая'][8],
        'Ель.1': kkk['таблица']['Е']['дровяная'][8],
        'Ель.2': kkk['таблица']['Е']['деловая'][12],
        'Ель.3': kkk['таблица']['Е']['дровяная'][12],
        'Ель.4': kkk['таблица']['Е']['деловая'][16],
        'Ель.5': kkk['таблица']['Е']['дровяная'][16],
        'Ель.6': kkk['таблица']['Е']['деловая'][20],
        'Ель.7': kkk['таблица']['Е']['дровяная'][20],
        'Ель.8': kkk['таблица']['Е']['деловая'][24],
        'Ель.9': kkk['таблица']['Е']['дровяная'][24],
        'Ель.10': kkk['таблица']['Е']['деловая'][28],
        'Ель.11': kkk['таблица']['Е']['дровяная'][28],
        'Ель.12': kkk['таблица']['Е']['деловая'][32],
        'Ель.13': kkk['таблица']['Е']['дровяная'][32]
        }

        for index in filtered_row_index:
            excel_df.loc[index, list(new_values_el.keys())] = list(new_values_el.values())
    except:
        continue


    try:
        new_values_ber = {
        'Береза': kkk['таблица']['Б']['деловая'][8],
        'Береза.1': kkk['таблица']['Б']['дровяная'][8],
        'Береза.2': kkk['таблица']['Б']['деловая'][12],
        'Береза.3': kkk['таблица']['Б']['дровяная'][12],
        'Береза.4': kkk['таблица']['Б']['деловая'][16],
        'Береза.5': kkk['таблица']['Б']['дровяная'][16],
        'Береза.6': kkk['таблица']['Б']['деловая'][20],
        'Береза.7': kkk['таблица']['Б']['дровяная'][20],
        'Береза.8': kkk['таблица']['Б']['деловая'][24],
        'Береза.9': kkk['таблица']['Б']['дровяная'][24],
        'Береза.10': kkk['таблица']['Б']['деловая'][28],
        'Береза.11': kkk['таблица']['Б']['дровяная'][28],
        'Береза.12': kkk['таблица']['Б']['деловая'][32],
        'Береза.13': kkk['таблица']['Б']['дровяная'][32]

        }

        for index in filtered_row_index:
            excel_df.loc[index, list(new_values_ber.keys())] = list(new_values_ber.values())

    except:
        continue    

    try:
        new_values_lis = {
        'Лиственница': kkk['таблица']['Л']['деловая'][8],
        'Лиственница.1': kkk['таблица']['Л']['дровяная'][8],
        'Лиственница.2': kkk['таблица']['Л']['деловая'][12],
        'Лиственница.3': kkk['таблица']['Л']['дровяная'][12],
        'Лиственница.4': kkk['таблица']['Л']['деловая'][16],
        'Лиственница.5': kkk['таблица']['Л']['дровяная'][16],
        'Лиственница.6': kkk['таблица']['Л']['деловая'][20],
        'Лиственница.7': kkk['таблица']['Л']['дровяная'][20],
        'Лиственница.8': kkk['таблица']['Л']['деловая'][24],
        'Лиственница.9': kkk['таблица']['Л']['дровяная'][24],
        'Лиственница.10': kkk['таблица']['Л']['деловая'][28],
        'Лиственница.11': kkk['таблица']['Л']['дровяная'][28],
        'Лиственница.12': kkk['таблица']['Л']['деловая'][32],
        'Лиственница.13': kkk['таблица']['Л']['дровяная'][32]
        }
        
        for index in filtered_row_index:
            excel_df.loc[index, list(new_values_lis.keys())] = list(new_values_lis.values())
    except:
        continue

# %%
columns_to_convert = [
'Ель',
 'Ель.1',
 'Ель.2',
 'Ель.3',
 'Ель.4',
 'Ель.5',
 'Ель.6',
 'Ель.7',
 'Ель.8',
 'Ель.9',
 'Ель.10',
 'Ель.11',
 'Ель.12',
 'Ель.13',
 'Береза',
 'Береза.1',
 'Береза.2',
 'Береза.3',
 'Береза.4',
 'Береза.5',
 'Береза.6',
 'Береза.7',
 'Береза.8',
 'Береза.9',
 'Береза.10',
 'Береза.11',
 'Береза.12',
 'Береза.13',
 'Лиственница',
 'Лиственница.1',
 'Лиственница.2',
 'Лиственница.3',
 'Лиственница.4',
 'Лиственница.5',
 'Лиственница.6',
 'Лиственница.7',
 'Лиственница.8',
 'Лиственница.9',
 'Лиственница.10',
 'Лиственница.11',
 'Лиственница.12',
 'Лиственница.13'
]

for column in columns_to_convert:
    if column in excel_df.columns:
        # Заменить пустые строки на NaN
        excel_df[column] = excel_df[column].replace('', np.nan)
        # Преобразовать в числовой формат, заменяя нечисловые значения на NaN, и затем на 0
        excel_df.loc[2:, column] = pd.to_numeric(excel_df.loc[2:, column], errors='coerce').fillna(0).astype(int)

# %%
excel_df = excel_df.replace(0,np.nan)

# %%
excel_df.to_excel('result.xlsx')

# %%
def find_table(kvartal, videl, area):
    for k in full_list:
        if (k['квартал'] == kvartal)&(k['выдел'] == videl)&(k['площадь'] == area):
            return k['таблица']
        else:
            continue

# %%
excel_df = pd.read_excel('add_kniga.xlsx')

# %%
excel_df[(excel_df['Квартал']==520)&(excel_df['Выдел, который пишем в ведомостях']==31)&(excel_df['Площадь']==1.455)]
# Out:
#   Квартал Выдел, который пишем в ведомостях Площадь  Ель Ель.1 Ель.2 Ель.3  \
# 7     520                                31   1.455  NaN   NaN   NaN   NaN
#
#   Ель.4 Ель.5 Ель.6  ... Лиственница Лиственница.1 Лиственница.2  \
# 7   NaN   NaN   NaN  ...         NaN           NaN           NaN
#
#   Лиственница.3 Лиственница.4 Лиственница.5 Лиственница.6 Лиственница.7  \
# 7           NaN           NaN           NaN           NaN           NaN
#
#   Лиственница.8 Лиственница.9
# 7           NaN           NaN
#
# [1 rows x 33 columns]

# %%
for index, row in excel_df.iloc[2:].iterrows():
    print(f"Index: {index}, Row: {row}")
# Out:
# Index: 2, Row: Unnamed: 0          520
# Unnamed: 1           31
# Unnamed: 2       0.4275
# Ель                 NaN
# Ель.1               NaN
# Ель.2               NaN
# Ель.3               NaN
# Ель.4               NaN
# Ель.5               NaN
# Ель.6               NaN
# Ель.7               NaN
# Ель.8               NaN
# Ель.9               NaN
# Береза              NaN
# Береза.1            NaN
# Береза.2            NaN
# Береза.3            NaN
# Береза.4            NaN
# Береза.5            NaN
# Береза.6            NaN
# Береза.7            NaN
# Береза.8            NaN
# Береза.9            NaN
# Лиственница         NaN
# Лиственница.1       NaN
# Лиственница.2       NaN
# Лиственница.3       NaN
# Лиственница.4       NaN
# Лиственница.5       NaN
# Лиственница.6       NaN
# Лиственница.7       NaN
# Лиственница.8       NaN
# Лиственница.9       NaN
# Name: 2, dtype: object
# Index: 3, Row: Unnamed: 0           520
# Unnamed: 1            15
# Unnamed: 2       0.42635
# ...

# %% [markdown]
# ### Собор данных ведомости по варианту 2 (Таня больше у него заказывать не будет)

# %%
### впиши сюда путь к новым файлам ведомостей

new_path = 'docs'
new_files = [f for f in os.listdir(new_path) if f != '.DS_Store']

# %%
full_list = []

for file_link in new_files:

    doc = Document(f'docs/{file_link}')

    full_text = []
    for paragraph in doc.paragraphs:
        full_text.append(paragraph.text)

    list_full = []

    for i in full_text:
        list_full.append(i.split('   '))

    def flatten_list(nested_list):
        flat_list = []
        for item in nested_list:
            if isinstance(item, list):
                flat_list.extend(flatten_list(item)) 
            else:
                flat_list.append(item)
        return flat_list

    list_full = flatten_list(list_full)


    kvartal = int(list_full[list_full.index('квартал №')+1].strip())
    videl = int(list_full[list_full.index('  выдел №')+1].strip())
    area = float(list_full[list_full.index('  экспл. площадь')+1].replace('га','').strip().replace(',','.'))



    table_second = doc.tables[0]

    def get_data_les(index):
        poroda_cell = table_second.rows[1].cells[index].text[0]
        delovaya_dict = {
            8:table_second.rows[7].cells[index].text.strip(),
            12:table_second.rows[8].cells[index].text.strip(),
            16:table_second.rows[9].cells[index].text.strip(),
            20:table_second.rows[10].cells[index].text.strip(),
            24:table_second.rows[11].cells[index].text.strip(),
            28:table_second.rows[12].cells[index].text.strip(),
            32:table_second.rows[13].cells[index].text.strip(),
            36:table_second.rows[14].cells[index].text.strip(),
            40:table_second.rows[15].cells[index].text.strip(),
            44:table_second.rows[16].cells[index].text.strip(),
            48:table_second.rows[17].cells[index].text.strip()
        }
        
        polu_delovaya_dict = {
            8:table_second.rows[7].cells[index+1].text.strip(),
            12:table_second.rows[8].cells[index+1].text.strip(),
            16:table_second.rows[9].cells[index+1].text.strip(),
            20:table_second.rows[10].cells[index+1].text.strip(),
            24:table_second.rows[11].cells[index+1].text.strip(),
            28:table_second.rows[12].cells[index+1].text.strip(),
            32:table_second.rows[13].cells[index+1].text.strip(),
            36:table_second.rows[14].cells[index+1].text.strip(),
            40:table_second.rows[15].cells[index+1].text.strip(),
            44:table_second.rows[16].cells[index+1].text.strip(),
            48:table_second.rows[17].cells[index+1].text.strip()
        }

        drovyanaya_dict = {
            8:table_second.rows[7].cells[index+2].text.strip(),
            12:table_second.rows[8].cells[index+2].text.strip(),
            16:table_second.rows[9].cells[index+2].text.strip(),
            20:table_second.rows[10].cells[index+2].text.strip(),
            24:table_second.rows[11].cells[index+2].text.strip(),
            28:table_second.rows[12].cells[index+2].text.strip(),
            32:table_second.rows[13].cells[index+2].text.strip(),
            36:table_second.rows[14].cells[index+2].text.strip(),
            40:table_second.rows[15].cells[index+2].text.strip(),
            44:table_second.rows[16].cells[index+2].text.strip(),
            48:table_second.rows[17].cells[index+2].text.strip()
        }
        
        return poroda_cell, delovaya_dict, polu_delovaya_dict, drovyanaya_dict

    list_porod = {}

    if table_second.rows[1].cells[1].text:
        poroda_cell_1, delovaya_dict_1, polu_delovaya_dict_1, drovyanaya_dict_1 = get_data_les(1)
        list_porod[poroda_cell_1] = {
            'деловая': delovaya_dict_1,
            'полуделовая': polu_delovaya_dict_1,
            'дровяная': drovyanaya_dict_1
        }
        
    if table_second.rows[1].cells[5].text:
        poroda_cell_2, delovaya_dict_2, polu_delovaya_dict_2, drovyanaya_dict_2 = get_data_les(5)
        list_porod[poroda_cell_2] = {
            'деловая': delovaya_dict_2,
            'полуделовая': polu_delovaya_dict_2,
            'дровяная': drovyanaya_dict_2
        }
        
    if table_second.rows[1].cells[8].text:
        poroda_cell_3, delovaya_dict_3, polu_delovaya_dict_3, drovyanaya_dict_3 = get_data_les(8)
        list_porod[poroda_cell_3] = {
            'деловая': delovaya_dict_3,
            'полуделовая': polu_delovaya_dict_3,
            'дровяная': drovyanaya_dict_3
        }
        
    if table_second.rows[1].cells[11].text:
        poroda_cell_4, delovaya_dict_4, polu_delovaya_dict_4, drovyanaya_dict_4 = get_data_les(11)
        list_porod[poroda_cell_4] = {
            'деловая': delovaya_dict_4,
            'полуделовая': polu_delovaya_dict_4,
            'дровяная': drovyanaya_dict_4
        }
        
    dict_i = {'квартал':kvartal,
            'выдел':videl,
            'площадь':area,
            'таблица':list_porod}

    full_list.append(dict_i)

# %%
full_list
# Out:
# [{'квартал': 236,
#   'выдел': 37,
#   'площадь': 0.019,
#   'таблица': {'Е': {'деловая': {8: '3',
#      12: '2',
#      16: '3',
#      20: '',
#      24: '',
#      28: '',
#      32: '',
#      36: '',
#      40: '',
#      44: '',
#      48: ''},
#     'полуделовая': {8: '',
#      12: '',
#      16: '',
#      20: '',
#      24: '',
#      28: '',
#      32: '',
#      36: '',
#      40: '',
#      44: '',
#      48: ''},
#     'дровяная': {8: '',
#      12: '',
#      16: '',
#      20: '',
#      24: '',
#      28: '',
#      32: '',
#      36: '',
#      40: '',
#      44: '',
#      48: ''}},
#    'Б': {'деловая': {8: '2',
#      12: '2',
#      16: '',
#      20: '',
#      24: '',
#      28: '',
#      32: '',
#      36: '',
#      40: '',
#      44: '',
#      48: ''},
#     'полуделовая': {8: '1',
#      12: '1',
#      16: '',
#      20: '',
#      24: '',
#      28: '',
#      32: '',
#      36: '',
#      40: '',
#      44: '',
#      48: ''},
# ...
